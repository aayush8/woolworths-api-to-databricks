# %%
import requests
import os
from dotenv import load_dotenv

load_dotenv()

url = "https://woolworths-products-api.p.rapidapi.com/woolworths/product-search/"

querystring = {"query":"Kraft Singles"}

headers = {
	"x-rapidapi-key": os.getenv("RAPIDAPI_KEY"),
	"x-rapidapi-host": "woolworths-products-api.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'query': 'Kraft Singles', 'results': [{'barcode': 9316389194805, 'product_name': 'Kraft Singles Original ORIGINAL', 'product_brand': 'Kraft', 'current_price': 9.6, 'product_size': '432g', 'url': 'https://www.woolworths.com.au/shop/productdetails/791364'}, {'barcode': 9316389194904, 'product_name': 'Kraft Singles Original ORIGINAL', 'product_brand': 'Kraft', 'current_price': 4.4, 'product_size': '216g', 'url': 'https://www.woolworths.com.au/shop/productdetails/791361'}, {'barcode': 9316389195703, 'product_name': 'Kraft Singles Light 25% Less Fat', 'product_brand': 'Kraft', 'current_price': 9.6, 'product_size': '432g', 'url': 'https://www.woolworths.com.au/shop/productdetails/791784'}, {'barcode': 9339687305117, 'product_name': 'Kraft Manilla Folder', 'product_brand': 'Kraft', 'current_price': 2.8, 'product_size': '10 pack', 'url': 'https://www.woolworths.com.au/shop/productdetails/228129'}, {'barcode': 9339687305094, 'product_name': 'Kraft Ring Binder', 'product_brand': 'Kraft', 'current_price': 2.8, 'product_size': 'each', 'url': 'https://www.woolworths.com.au/shop/productdetails/228128'}, {'barcode': 6084012090673, 'product_name': 'Kraft Cheddar Cheese Block', 'product_brand': 'Kraft', 'current_price': 6.5, 'product_size': '250g', 'url': 'https://www.woolworths.com.au/shop/productdetails/194717'}, {'barcode': 9316389195604, 'product_name': 'Kraft Grated Parmesan Cheese', 'product_brand': 'Kraft', 'current_price': 5.95, 'product_size': '125g', 'url': 'https://www.woolworths.com.au/shop/productdetails/33599'}, {'barcode': 9316389198001, 'product_name': 'Kraft Bluey Mild Cheese Sticks', 'product_brand': 'Kraft', 'current_price': 6.7, 'product_size': '10 pack', 'url': 'https://www.woolworths.com.au/shop/productdetails/410455'}, {'barcode': 9316389195505, 'product_name': 'Kraft Grated Parmesan Cheese Cannister', 'product_brand': 'Kraft', 'current_price': 10.35, 'product_size': '250g', 'url': 'https://www.woolworths.com.au/shop/productdetails/35143'}, {'barcode': 9316389197905, 'product_name': 'Kraft Bluey Mild Cheese Sticks', 'product_brand': 'Kraft', 'current_price': 4.0, 'product_size': '5 pack', 'url': 'https://www.woolworths.com.au/shop/productdetails/420584'}], 'total_results': 715, 'total_pages': 72, 'current_page': 1}
